# %% [markdown]
# All the libraries are imported here.Also warning bypass is done here.

# %%
import os
import warnings
import numpy as np
import librosa
import cv2
import tensorflow as tf
from tensorflow.keras.utils import Sequence
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Concatenate, Dropout, BatchNormalization, Conv3D, MaxPooling3D, Flatten, Activation, Conv2D, MaxPooling2D, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import train_test_split

# Suppress TensorFlow logging
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Suppress specific Python warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)

# Suppress TensorFlow retracing warnings
tf.get_logger().setLevel('ERROR')

# %% [markdown]
# As the label of the dataset is in file name and the format for it is given "03-02-01-01-02-01-02.wav" as this so a function to get the audio label is created here.

# %%
# Emotion mapping
emotion_dict = {
    '01': 'neutral',
    '02': 'calm',
    '03': 'happy',
    '04': 'sad',
    '05': 'angry',
    '06': 'fearful',
    '07': 'disgust',
    '08': 'surprised'
}

emotion_labels = list(emotion_dict.values())

def parse_label_from_filename(file_name):
    parts = file_name.split('-')
    actor_id = parts[-1].split('.')[0]  
    emotion_id = parts[2]
    return actor_id, emotion_dict[emotion_id]

# %% [markdown]
# #For audio:

# %%
# Feature extraction for audio with augmentation
def extract_audio_features(file_path, target_time_steps=44):
    try:
        y, sr = librosa.load(file_path, sr=22050)
        
        # Audio augmentations
        if np.random.rand() < 0.4:
            y = librosa.effects.pitch_shift(y=y, sr=sr, n_steps=np.random.uniform(-2, 2))  # Pitch shift
        if np.random.rand() < 0.4:
            y = librosa.effects.time_stretch(y=y, rate=np.random.uniform(0.7, 1.3))  # Time stretch
        if np.random.rand() < 0.4:
            y += 0.01 * np.random.randn(len(y))  # Add noise

        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)  # Shape: (40, time_steps)

        # Adjust the time steps to the target length (44)
        if mfccs.shape[1] > target_time_steps:
            mfccs = mfccs[:, :target_time_steps]  # Truncate
        elif mfccs.shape[1] < target_time_steps:
            pad_width = target_time_steps - mfccs.shape[1]
            mfccs = np.pad(mfccs, ((0, 0), (0, pad_width)), mode='constant')  # Pad with zeros

        return mfccs
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return np.zeros((40, target_time_steps))  # Default size for consistency


# Feature extraction for video with sequence length adjustment
def extract_video_features(video_frames, sequence_length):
    frames = np.array([cv2.resize(frame, (112, 112)) for frame in video_frames])
    
    if len(frames) > sequence_length:
        frames = frames[:sequence_length]
    elif len(frames) < sequence_length:
        padding = np.zeros((sequence_length - len(frames), 112, 112, 3))
        frames = np.concatenate((frames, padding))
    
    frames = frames.reshape(-1, sequence_length, 112, 112, 3)  # Shape: (batch_size, sequence_length, height, width, channels)
    return frames

# %%
# Data generator
class DataGenerator(Sequence):
    def __init__(self, audio_files, video_files, batch_size=32, sequence_length=20, dim=(224,224), shuffle=True, **kwargs):
        self.audio_files = audio_files
        self.video_files = video_files
        self.batch_size = batch_size
        self.sequence_length = sequence_length
        self.dim = dim
        self.shuffle = shuffle
        self.indexes = np.arange(len(self.audio_files))
        super().__init__(**kwargs)  # Call the base class constructor with kwargs
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.audio_files) / self.batch_size))

    def __getitem__(self, index):
        # Generate a batch of audio and video files
        batch_audio_files = self.audio_files[index * self.batch_size:(index + 1) * self.batch_size]
        batch_video_files = self.__match_video_files(batch_audio_files)
        
        X_audio, y_audio = self.__data_generation_audio(batch_audio_files)
        X_video, y_video = self.__data_generation_video(batch_video_files)
        
        # Ensure the labels are consistent (e.g., for now, using y_audio)
        return (X_audio, X_video), y_audio

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.audio_files)
            np.random.shuffle(self.video_files)

    def __match_video_files(self, batch_audio_files):
        matched_video_files = []
        for audio_file in batch_audio_files:
            actor_id, emotion_label = parse_label_from_filename(os.path.basename(audio_file))
            for video_file in self.video_files:
                video_actor_id, video_emotion_label = parse_label_from_filename(os.path.basename(video_file))
                if actor_id == video_actor_id and emotion_label == video_emotion_label:
                    matched_video_files.append(video_file)
                    break
        return matched_video_files

    # Data generation for audio
    def __data_generation_audio(self, batch_audio_files):
        X_audio = np.empty((self.batch_size, 40, 44, 1))  # Adjust shape to (40, 44, 1)
        y = np.empty((self.batch_size), dtype=int)

        for i, audio_path in enumerate(batch_audio_files):
            mel_spec = extract_audio_features(audio_path)
            mel_spec = np.expand_dims(mel_spec, axis=-1)  # Add channel dimension
            X_audio[i,] = mel_spec  # Ensure MFCC shape matches (40, 44, 1)
            label = parse_label_from_filename(os.path.basename(audio_path))[1]
            y[i] = emotion_labels.index(label)

        return X_audio, y


    def __data_generation_video(self, batch_video_files):
        X_video = np.empty((self.batch_size, self.sequence_length, 112, 112, 3))
        y = np.empty((self.batch_size), dtype=int)

        for i, video_path in enumerate(batch_video_files):
            cap = cv2.VideoCapture(video_path)
            frames = []
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                frames.append(frame)
            cap.release()
            
            if len(frames) == 0:
                raise ValueError(f"No frames extracted from video file {video_path}")
            
            X_video[i,] = extract_video_features(np.array(frames), self.sequence_length)
            label = parse_label_from_filename(os.path.basename(video_path))[1]
            y[i] = emotion_labels.index(label)

        return X_video, y

# %%
# File paths
audio_dir = 'dataset/audios'
video_dir = 'dataset/videos'
audio_files = []
video_files = []

# Populate the lists by reading from directories
for actor_dir in os.listdir(audio_dir):
    actor_path = os.path.join(audio_dir, actor_dir)
    if os.path.isdir(actor_path):
        for file in os.listdir(actor_path):
            if file.endswith('.wav'):
                audio_files.append(os.path.join(actor_path, file))

for actor_dir in os.listdir(video_dir):
    actor_path = os.path.join(video_dir, actor_dir)
    if os.path.isdir(actor_path):
        for file in os.listdir(actor_path):
            if file.endswith('.mp4'):
                video_files.append(os.path.join(actor_path, file))

# Debugging: Check the number of audio and video files
print(f"Total audio files: {len(audio_files)}")
print(f"Total video files: {len(video_files)}")
# Out:
# Total audio files: 264
# Total video files: 528

# %%
# Split the data into training and validation sets
audio_train, audio_val = train_test_split(audio_files, test_size=0.2, random_state=42)
video_train, video_val = train_test_split(video_files, test_size=0.2, random_state=42)

# Create training and validation generators
SEQUENCE_LENGTH = 20  # Fixed sequence length
train_generator = DataGenerator(audio_train, video_train, batch_size=16, sequence_length=SEQUENCE_LENGTH)
val_generator = DataGenerator(audio_val, video_val, batch_size=16, sequence_length=SEQUENCE_LENGTH)

# %%
# Model definition

IMAGE_HEIGHT, IMAGE_WIDTH = 112, 112

# Audio input branch with Conv2D layers
input_audio = Input(shape=(40, 44, 1))  # Adjust shape for 2D convolution
x_audio = Conv2D(32, (3, 3), activation='relu')(input_audio)
x_audio = BatchNormalization()(x_audio)
x_audio = MaxPooling2D((2, 2))(x_audio)

x_audio = Conv2D(64, (3, 3), activation='relu')(x_audio)
x_audio = BatchNormalization()(x_audio)
x_audio = MaxPooling2D((2, 2))(x_audio)

x_audio = Flatten()(x_audio)
x_audio = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x_audio)
x_audio = BatchNormalization()(x_audio)
x_audio = Dropout(0.5)(x_audio)

# Video input branch using 3D Conv layers
input_video = Input(shape=(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3))  # Adjusted input shape for sequence of frames
x_video = Conv3D(16, (3, 3, 3), activation='relu')(input_video)
x_video = BatchNormalization()(x_video)
x_video = MaxPooling3D((1, 2, 2))(x_video)

x_video = Conv3D(32, (3, 3, 3), activation='relu')(x_video)
x_video = BatchNormalization()(x_video)
x_video = MaxPooling3D((1, 2, 2))(x_video)

x_video = Conv3D(64, (3, 3, 3), activation='relu')(x_video)
x_video = BatchNormalization()(x_video)
x_video = MaxPooling3D((1, 2, 2))(x_video)

x_video = Flatten()(x_video)
x_video = Dense(2048, activation='relu')(x_video)
x_video = Dropout(0.5)(x_video)
x_video = Dense(1024, activation='relu')(x_video)
x_video = Dropout(0.5)(x_video)

# Combine audio and video branches
combined = Concatenate()([x_audio, x_video])
x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(combined)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
output = Dense(len(emotion_dict), activation='softmax')(x)

# %%
# Compile the model
optimizer = Adam(learning_rate=0.0005, clipnorm=1.0)  # Gradient clipping
model = Model(inputs=[input_audio, input_video], outputs=output)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 20, 112,   │          0 │ -                 │
# │ (InputLayer)        │ 112, 3)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_3 (Conv3D)   │ (None, 18, 110,   │      1,312 │ input_layer_3[0]… │
# │                     │ 110, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 18, 110,   │         64 │ conv3d_3[0][0]    │
# │ (BatchNormalizatio… │ 110, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_3     │ (None, 18, 55,    │          0 │ batch_normalizat… │
# │ (MaxPooling3D)      │ 55, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_2       │ (None, 40, 44, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_4 (Conv3D)   │ (None, 16, 53,    │     13,856 │ max_pooling3d_3[… │
# │                     │ 53, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 38, 42,    │        320 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 53,    │        128 │ conv3d_4[0][0]    │
# │ (BatchNormalizatio… │ 53, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 38, 42,    │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_4     │ (None, 16, 26,    │          0 │ batch_normalizat… │
# │ (MaxPooling3D)      │ 26, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 19, 21,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_5 (Conv3D)   │ (None, 14, 24,    │     55,360 │ max_pooling3d_4[… │
# │                     │ 24, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 17, 19,    │     18,496 │ max_pooling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 24,    │        256 │ conv3d_5[0][0]    │
# │ (BatchNormalizatio… │ 24, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 19,    │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_5     │ (None, 14, 12,    │          0 │ batch_normalizat… │
# │ (MaxPooling3D)      │ 12, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 9, 64)  │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_3 (Flatten) │ (None, 129024)    │          0 │ max_pooling3d_5[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 4608)      │          0 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 2048)      │ 264,243,2… │ flatten_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │    589,952 │ flatten_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 2048)      │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_5[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 1024)      │  2,098,176 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 1024)      │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 1152)      │          0 │ dropout_4[0][0],  │
# │ (Concatenate)       │                   │            │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 512)       │    590,336 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_8[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 8)         │      4,104 │ dropout_7[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 267,618,504 (1020.88 MB)
#  Trainable params: 267,616,808 (1020.88 MB)
#  Non-trainable params: 1,696 (6.62 KB)

# %%
# Callbacks for early stopping, model checkpointing, and learning rate reduction
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)  # Increased patience
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)
# Training with validation data
history = model.fit(train_generator, validation_data=val_generator, epochs=50, callbacks=[checkpoint, early_stopping, reduce_lr])
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.1535 - loss: 4.5062
# Epoch 1: val_accuracy improved from -inf to 0.00000, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 6s/step - accuracy: 0.1518 - loss: 4.4954 - val_accuracy: 0.0000e+00 - val_loss: 5.5336 - learning_rate: 5.0000e-04
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.1772 - loss: 3.9874
# Epoch 2: val_accuracy improved from 0.00000 to 0.20833, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 99s 5s/step - accuracy: 0.1779 - loss: 3.9878 - val_accuracy: 0.2083 - val_loss: 3.0360 - learning_rate: 5.0000e-04
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.1398 - loss: 4.4014
# Epoch 3: val_accuracy did not improve from 0.20833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.1408 - loss: 4.3863 - val_accuracy: 0.1875 - val_loss: 3.1214 - learning_rate: 5.0000e-04
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2332 - loss: 3.7078
# Epoch 4: val_accuracy did not improve from 0.20833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.2310 - loss: 3.7156 - val_accuracy: 0.1667 - val_loss: 3.0536 - learning_rate: 5.0000e-04
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.1838 - loss: 3.8012
# Epoch 5: val_accuracy did not improve from 0.20833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.1841 - loss: 3.7979 - val_accuracy: 0.1667 - val_loss: 3.0563 - learning_rate: 5.0000e-04
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2206 - loss: 3.5682
# Epoch 6: val_accuracy did not improve from 0.20833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.2217 - loss: 3.5649 - val_accuracy: 0.1875 - val_loss: 3.0406 - learning_rate: 5.0000e-04
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.1724 - loss: 3.7195
# Epoch 7: val_accuracy did not improve from 0.20833
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 108s 6s/step - accuracy: 0.1721 - loss: 3.7205 - val_accuracy: 0.0417 - val_loss: 4.2931 - learning_rate: 5.0000e-04
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2048 - loss: 3.6031
# Epoch 8: val_accuracy improved from 0.20833 to 0.25000, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 98s 5s/step - accuracy: 0.2059 - loss: 3.5996 - val_accuracy: 0.2500 - val_loss: 3.6466 - learning_rate: 2.5000e-04
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.1513 - loss: 3.8369
# Epoch 9: val_accuracy did not improve from 0.25000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 94s 5s/step - accuracy: 0.1508 - loss: 3.8369 - val_accuracy: 0.1875 - val_loss: 4.8242 - learning_rate: 2.5000e-04
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.1494 - loss: 3.6836
# Epoch 10: val_accuracy did not improve from 0.25000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 94s 5s/step - accuracy: 0.1483 - loss: 3.6930 - val_accuracy: 0.1875 - val_loss: 3.4880 - learning_rate: 2.5000e-04
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2259 - loss: 3.4897
# Epoch 11: val_accuracy did not improve from 0.25000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 95s 5s/step - accuracy: 0.2263 - loss: 3.4904 - val_accuracy: 0.2292 - val_loss: 2.7691 - learning_rate: 2.5000e-04
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2644 - loss: 3.1631
# Epoch 12: val_accuracy did not improve from 0.25000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 94s 5s/step - accuracy: 0.2644 - loss: 3.1675 - val_accuracy: 0.1667 - val_loss: 2.9637 - learning_rate: 2.5000e-04
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2603 - loss: 3.8187
# Epoch 13: val_accuracy did not improve from 0.25000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 94s 5s/step - accuracy: 0.2599 - loss: 3.8054 - val_accuracy: 0.1667 - val_loss: 3.3267 - learning_rate: 2.5000e-04
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2215 - loss: 3.4702
# Epoch 14: val_accuracy improved from 0.25000 to 0.35417, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 98s 5s/step - accuracy: 0.2232 - loss: 3.4694 - val_accuracy: 0.3542 - val_loss: 2.6545 - learning_rate: 2.5000e-04
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2752 - loss: 3.3560
# Epoch 15: val_accuracy did not improve from 0.35417
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 95s 5s/step - accuracy: 0.2748 - loss: 3.3540 - val_accuracy: 0.2500 - val_loss: 2.4041 - learning_rate: 2.5000e-04
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2179 - loss: 3.1420
# Epoch 16: val_accuracy did not improve from 0.35417
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 95s 5s/step - accuracy: 0.2212 - loss: 3.1357 - val_accuracy: 0.3333 - val_loss: 2.3619 - learning_rate: 2.5000e-04
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2986 - loss: 3.1249
# Epoch 17: val_accuracy did not improve from 0.35417
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 95s 5s/step - accuracy: 0.2993 - loss: 3.1170 - val_accuracy: 0.2500 - val_loss: 2.7195 - learning_rate: 2.5000e-04
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3025 - loss: 3.0223
# Epoch 18: val_accuracy improved from 0.35417 to 0.39583, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 98s 5s/step - accuracy: 0.3032 - loss: 3.0171 - val_accuracy: 0.3958 - val_loss: 2.4953 - learning_rate: 2.5000e-04
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2095 - loss: 3.2820
# Epoch 19: val_accuracy did not improve from 0.39583
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 95s 5s/step - accuracy: 0.2110 - loss: 3.2717 - val_accuracy: 0.3750 - val_loss: 2.4558 - learning_rate: 2.5000e-04
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3046 - loss: 2.8370
# Epoch 20: val_accuracy did not improve from 0.39583
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 94s 5s/step - accuracy: 0.3052 - loss: 2.8366 - val_accuracy: 0.3958 - val_loss: 2.2439 - learning_rate: 2.5000e-04
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2965 - loss: 3.0824
# Epoch 21: val_accuracy improved from 0.39583 to 0.45833, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 97s 5s/step - accuracy: 0.2966 - loss: 3.0780 - val_accuracy: 0.4583 - val_loss: 2.2068 - learning_rate: 2.5000e-04
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3418 - loss: 2.7244
# Epoch 22: val_accuracy did not improve from 0.45833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.3421 - loss: 2.7196 - val_accuracy: 0.3333 - val_loss: 2.3822 - learning_rate: 2.5000e-04
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2956 - loss: 3.0846
# Epoch 23: val_accuracy did not improve from 0.45833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.2992 - loss: 3.0680 - val_accuracy: 0.3750 - val_loss: 2.4879 - learning_rate: 2.5000e-04
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3721 - loss: 2.6834
# Epoch 24: val_accuracy did not improve from 0.45833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.3692 - loss: 2.6876 - val_accuracy: 0.2708 - val_loss: 2.5533 - learning_rate: 2.5000e-04
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4562 - loss: 2.5596
# Epoch 25: val_accuracy did not improve from 0.45833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 94s 5s/step - accuracy: 0.4528 - loss: 2.5529 - val_accuracy: 0.3750 - val_loss: 2.2163 - learning_rate: 2.5000e-04
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3598 - loss: 2.6739
# Epoch 26: val_accuracy did not improve from 0.45833
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.3626 - loss: 2.6684 - val_accuracy: 0.1458 - val_loss: 3.0390 - learning_rate: 2.5000e-04
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4609 - loss: 2.2027
# Epoch 27: val_accuracy did not improve from 0.45833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.4600 - loss: 2.2049 - val_accuracy: 0.3750 - val_loss: 1.9836 - learning_rate: 1.2500e-04
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4592 - loss: 2.2060
# Epoch 28: val_accuracy did not improve from 0.45833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.4614 - loss: 2.2045 - val_accuracy: 0.3542 - val_loss: 2.4642 - learning_rate: 1.2500e-04
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4423 - loss: 2.3872
# Epoch 29: val_accuracy did not improve from 0.45833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.4444 - loss: 2.3754 - val_accuracy: 0.2917 - val_loss: 2.3917 - learning_rate: 1.2500e-04
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4675 - loss: 2.1053
# Epoch 30: val_accuracy did not improve from 0.45833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.4692 - loss: 2.1059 - val_accuracy: 0.3333 - val_loss: 2.1723 - learning_rate: 1.2500e-04
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5333 - loss: 1.9375
# Epoch 31: val_accuracy did not improve from 0.45833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 94s 5s/step - accuracy: 0.5343 - loss: 1.9373 - val_accuracy: 0.2083 - val_loss: 2.3993 - learning_rate: 1.2500e-04
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5052 - loss: 2.0815
# Epoch 32: val_accuracy did not improve from 0.45833
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.5069 - loss: 2.0783 - val_accuracy: 0.2292 - val_loss: 2.0364 - learning_rate: 1.2500e-04
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5553 - loss: 2.3084
# Epoch 33: val_accuracy did not improve from 0.45833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.5551 - loss: 2.2923 - val_accuracy: 0.3333 - val_loss: 2.6613 - learning_rate: 6.2500e-05
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5722 - loss: 1.9489
# Epoch 34: val_accuracy did not improve from 0.45833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.5735 - loss: 1.9392 - val_accuracy: 0.3750 - val_loss: 2.3007 - learning_rate: 6.2500e-05
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5874 - loss: 1.9212
# Epoch 35: val_accuracy did not improve from 0.45833
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.5870 - loss: 1.9183 - val_accuracy: 0.3958 - val_loss: 2.0065 - learning_rate: 6.2500e-05
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5736 - loss: 2.0860
# Epoch 36: val_accuracy improved from 0.45833 to 0.52083, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 96s 5s/step - accuracy: 0.5742 - loss: 2.0752 - val_accuracy: 0.5208 - val_loss: 1.8913 - learning_rate: 6.2500e-05
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5195 - loss: 1.8546
# Epoch 37: val_accuracy did not improve from 0.52083
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.5212 - loss: 1.8512 - val_accuracy: 0.4375 - val_loss: 2.1668 - learning_rate: 6.2500e-05
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6440 - loss: 1.6795
# Epoch 38: val_accuracy did not improve from 0.52083
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.6433 - loss: 1.6843 - val_accuracy: 0.3958 - val_loss: 2.3445 - learning_rate: 6.2500e-05
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6199 - loss: 1.7041
# Epoch 39: val_accuracy did not improve from 0.52083
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.6186 - loss: 1.7086 - val_accuracy: 0.5208 - val_loss: 2.1653 - learning_rate: 6.2500e-05
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5982 - loss: 1.8548
# Epoch 40: val_accuracy improved from 0.52083 to 0.72917, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 96s 5s/step - accuracy: 0.5984 - loss: 1.8561 - val_accuracy: 0.7292 - val_loss: 1.5171 - learning_rate: 6.2500e-05
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6948 - loss: 1.5256
# Epoch 41: val_accuracy did not improve from 0.72917
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.6915 - loss: 1.5298 - val_accuracy: 0.4792 - val_loss: 1.9543 - learning_rate: 6.2500e-05
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6227 - loss: 1.7168
# Epoch 42: val_accuracy did not improve from 0.72917
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.6204 - loss: 1.7237 - val_accuracy: 0.3333 - val_loss: 2.4627 - learning_rate: 6.2500e-05
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6532 - loss: 1.6036
# Epoch 43: val_accuracy did not improve from 0.72917
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.6543 - loss: 1.5997 - val_accuracy: 0.5417 - val_loss: 2.0234 - learning_rate: 6.2500e-05
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6280 - loss: 1.6890
# Epoch 44: val_accuracy did not improve from 0.72917
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.6271 - loss: 1.6929 - val_accuracy: 0.3750 - val_loss: 2.6474 - learning_rate: 6.2500e-05
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5810 - loss: 1.7525
# Epoch 45: val_accuracy did not improve from 0.72917
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.5862 - loss: 1.7401 - val_accuracy: 0.3750 - val_loss: 2.2162 - learning_rate: 6.2500e-05
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6029 - loss: 1.8092
# Epoch 46: val_accuracy did not improve from 0.72917
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.6069 - loss: 1.7944 - val_accuracy: 0.4167 - val_loss: 2.4083 - learning_rate: 3.1250e-05
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6760 - loss: 1.4870
# Epoch 47: val_accuracy did not improve from 0.72917
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.6789 - loss: 1.4819 - val_accuracy: 0.3958 - val_loss: 2.8654 - learning_rate: 3.1250e-05
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6202 - loss: 1.8244
# Epoch 48: val_accuracy did not improve from 0.72917
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.6213 - loss: 1.8179 - val_accuracy: 0.4167 - val_loss: 2.7637 - learning_rate: 3.1250e-05
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7358 - loss: 1.2759
# Epoch 49: val_accuracy did not improve from 0.72917
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.7361 - loss: 1.2777 - val_accuracy: 0.4375 - val_loss: 2.5172 - learning_rate: 3.1250e-05
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7227 - loss: 1.4649
# Epoch 50: val_accuracy did not improve from 0.72917
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 94s 5s/step - accuracy: 0.7219 - loss: 1.4632 - val_accuracy: 0.5833 - val_loss: 2.6754 - learning_rate: 3.1250e-05
